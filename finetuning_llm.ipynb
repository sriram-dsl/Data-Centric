# %% [markdown]
# <a href="https://colab.research.google.com/github/sriram-dsl/Data-Centric/blob/master/finetuning_llm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://docs.unsloth.ai/get-started/installing-+-updating).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# Read our **[Qwen3 Guide](https://docs.unsloth.ai/basics/qwen3-how-to-run-and-fine-tune)** and check out our new **[Dynamic 2.0](https://docs.unsloth.ai/basics/unsloth-dynamic-2.0-ggufs)** quants which outperforms other quantization methods!
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth vllm
else:
    # [NOTE] Do the below ONLY in Colab! Use [[pip install unsloth vllm]]
    # !pip install --no-deps unsloth vllm

# %%
#@title Colab Extra Install { display-mode: "form" }
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth vllm
else:
    # !pip install --no-deps unsloth vllm
    # [NOTE] Do the below ONLY in Colab! Use [[pip install unsloth vllm]]
    # Skip restarting message in Colab
    import sys, re, requests; modules = list(sys.modules.keys())
    for x in modules: sys.modules.pop(x) if "PIL" in x or "google" in x else None
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft "trl==0.15.2" triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf datasets huggingface_hub hf_transfer

    # vLLM requirements - vLLM breaks Colab due to reinstalling numpy
    f = requests.get("https://raw.githubusercontent.com/vllm-project/vllm/refs/heads/main/requirements/common.txt").content
    with open("vllm_requirements.txt", "wb") as file:
        file.write(re.sub(rb"(transformers|numpy|xformers)[^\n]{1,}\n", b"", f))
    # !pip install -r vllm_requirements.txt

# %% [markdown]
# ### Unsloth

# %% [markdown]
# Load up `Gemma 3 1B Instruct`, and set parameters

# %%
from unsloth import FastModel
import torch
max_seq_length = 1024

fourbit_models = [
    # 4bit dynamic quants for superior accuracy and low memory use
    "unsloth/gemma-3-1b-it-unsloth-bnb-4bit",
    "unsloth/gemma-3-4b-it-unsloth-bnb-4bit",
    "unsloth/gemma-3-12b-it-unsloth-bnb-4bit",
    "unsloth/gemma-3-27b-it-unsloth-bnb-4bit",

    # Other popular models!
    "unsloth/Llama-3.1-8B",
    "unsloth/Llama-3.2-3B",
    "unsloth/Llama-3.3-70B",
    "unsloth/mistral-7b-instruct-v0.3",
    "unsloth/Phi-4",
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastModel.from_pretrained(
    model_name = "unsloth/gemma-3-1b-it",
    max_seq_length = max_seq_length, # Choose any for long context!
    load_in_4bit = False,  # 4 bit quantization to reduce memory
    load_in_8bit = False, # [NEW!] A bit more accurate, uses 2x memory
    full_finetuning = False, # [NEW!] We have full finetuning now!
    # token = "hf_...", # use one if using gated models
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 05-10 05:58:19 [importing.py:53] Triton module has been replaced with a placeholder.
# INFO 05-10 05:58:19 [__init__.py:239] Automatically detected platform cuda.
# ==((====))==  Unsloth 2025.4.7: Fast Gemma3 patching. Transformers: 4.51.3. vLLM: 0.8.5.post1.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: Using float16 precision for gemma3 won't work! Using float32.
# Unsloth: QLoRA and full finetuning all not selected. Switching to 16bit LoRA.
# model.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/238 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/670 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/1.53k [00:00<?, ?B/s]

# %% [markdown]
# We now add LoRA adapters so we only need to update a small amount of parameters!

# %%
model = FastModel.get_peft_model(
    model,
    finetune_vision_layers     = False, # Turn off for just text!
    finetune_language_layers   = True,  # Should leave on!
    finetune_attention_modules = True,  # Attention good for GRPO
    finetune_mlp_modules       = True,  # SHould leave on always!

    r = 8,           # Larger = higher accuracy, but might overfit
    lora_alpha = 8,  # Recommended alpha == r at least
    lora_dropout = 0,
    bias = "none",
    random_state = 3407,
)
# Out:
# Unsloth: Making `model.base_model.model.model` require gradients

# %% [markdown]
# ### Data Prep
# <a name="Data"></a>
#
# We're using OpenAI's famous GSM8K dataset!

# %%
from datasets import load_dataset
dataset = load_dataset("openai/gsm8k", "main", split = "train")
dataset
# Out:
# README.md:   0%|          | 0.00/7.94k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/2.31M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/419k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/7473 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1319 [00:00<?, ? examples/s]
# Dataset({
#     features: ['question', 'answer'],
#     num_rows: 7473
# })

# %%
dataset = load_dataset("json", data_files="/content/gsm8k_formatted_qa_pairs.json", split="train")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# Let's look at the first row:

# %%
dataset[0]["question"]
# Out:
# 'The e-commerce website has a "Wants-based" customer segment, which accounts for 25% of total customers. The average order value from this segment is $125. If the website has a total of 1200 customers, what was the revenue generated from these Wants-based customer segment orders?'

# %%
dataset[0]["answer"]
# Out:
# 'Total number of customers of wants-based customer segment = 25% of 1200 total overal customers = <<0.25*1200=300>>\n\nstep 2: calculate the total revenue generated by the wants-based customer segmet = (300 * 125) = <<37500>> \n#### $37500'

# %% [markdown]
# We notice all answers like about have a ####, so we extract it:

# %%
def extract_hash_answer(text):
    if "####" not in text: return None
    return text.split("####")[1].strip()
extract_hash_answer(dataset[0]["answer"])
# Out:
# '20'

# %% [markdown]
# We now create a system prompt which can be customized. We add 4 extra symbols for working out or thinking / reasoning sections and a final answer:

# %%
reasoning_start = "<start_working_out>"
reasoning_end   = "<end_working_out>"
solution_start = "<SOLUTION>"
solution_end = "</SOLUTION>"

system_prompt = \
f"""You are given a problem.
Think about the problem and provide your working out.
Place it between {reasoning_start} and {reasoning_end}.
Then, provide your solution between {solution_start}{solution_end}"""
system_prompt
# Out:
# 'You are given a problem.\nThink about the problem and provide your working out.\nPlace it between <start_working_out> and <end_working_out>.\nThen, provide your solution between <SOLUTION></SOLUTION>'

# %% [markdown]
# Let's map the dataset! and see the first row:

# %%
dataset = dataset.map(lambda x: {
    "prompt" : [
        {"role": "system", "content": system_prompt},
        {"role": "user",   "content": x["question"]},
    ],
    "answer": extract_hash_answer(x["answer"]),
})
dataset[0]
# Out:
# Map:   0%|          | 0/15 [00:00<?, ? examples/s]
# {'question': 'The e-commerce website has a "Wants-based" customer segment, which accounts for 25% of total customers. The average order value from this segment is $125. If the website has a total of 1200 customers, what was the revenue generated from these Wants-based customer segment orders?',
#  'answer': '$37500',
#  'prompt': [{'content': 'You are given a problem.\nThink about the problem and provide your working out.\nPlace it between <start_working_out> and <end_working_out>.\nThen, provide your solution between <SOLUTION></SOLUTION>',
#    'role': 'system'},
#   {'content': 'The e-commerce website has a "Wants-based" customer segment, which accounts for 25% of total customers. The average order value from this segment is $125. If the website has a total of 1200 customers, what was the revenue generated from these Wants-based customer segment orders?',
#    'role': 'user'}]}

# %% [markdown]
# We create a regex format to match the reasoning sections and answers:

# %%
import re

match_format = re.compile(
    rf"^[\s]{{0,}}"\
    rf"{reasoning_start}.+?{reasoning_end}.*?"\
    rf"{solution_start}(.+?){solution_end}"\
    rf"[\s]{{0,}}$",
    flags = re.MULTILINE | re.DOTALL
)

# %% [markdown]
# We verify it works:

# %%
match_format.search(
    "<start_working_out>Let me think!<end_working_out>"\
    "<SOLUTION>2</SOLUTION>",
)
# Out:
# <re.Match object; span=(0, 71), match='<start_working_out>Let me think!<end_working_out>>

# %% [markdown]
# We now want to create a reward function to match the format exactly - we reward it with 3 points if it succeeds:

# %%
def match_format_exactly(completions, **kwargs):
    scores = []
    for completion in completions:
        score = 0
        response = completion[0]["content"]
        # Match if format is seen exactly!
        if match_format.search(response) is not None: score += 3.0
        scores.append(score)
    return scores

# %% [markdown]
# If it fails, we want to reward the model if it at least follows the format partially, by counting each symbol:

# %%
def match_format_approximately(completions, **kwargs):
    scores = []
    for completion in completions:
        score = 0
        response = completion[0]["content"]
        # Count how many keywords are seen - we penalize if too many!
        # If we see 1, then plus some points!
        score += 0.5 if response.count(reasoning_start) == 1 else -0.5
        score += 0.5 if response.count(reasoning_end)   == 1 else -0.5
        score += 0.5 if response.count(solution_start)  == 1 else -0.5
        score += 0.5 if response.count(solution_end)    == 1 else -0.5
        scores.append(score)
    return scores

# %% [markdown]
# Finally, we want to extract the generated answer, and reward or penalize it! We also reward it based on how close the answer is to the true one via ratios:

# %%
def check_answer(prompts, completions, answer, **kwargs):
    question = prompts[0][-1]["content"]
    responses = [completion[0]["content"] for completion in completions]

    extracted_responses = [
        guess.group(1)
        if (guess := match_format.search(r)) is not None else None \
        for r in responses
    ]

    scores = []
    for guess, true_answer in zip(extracted_responses, answer):
        score = 0
        if guess is None:
            scores.append(0)
            continue
        # Correct answer gets 3 points!
        if guess == true_answer:
            score += 3.0
        # Match if spaces are seen
        elif guess.strip() == true_answer.strip():
            score += 1.5
        else:
            # We also reward it if the answer is close via ratios!
            # Ie if the answer is within some range, reward it!
            try:
                ratio = float(guess) / float(true_answer)
                if   ratio >= 0.9 and ratio <= 1.1: score += 0.5
                elif ratio >= 0.8 and ratio <= 1.2: score += 0.25
                else: score -= 1.0 # Penalize wrong answers
            except:
                score -= 0.5 # Penalize
        scores.append(score)
    return scores

# %% [markdown]
# Also sometimes it might not be 1 number as the answer, but like a sentence for example "The solution is $20" -> we extract 20.

# %%
match_numbers = re.compile(
    rf"{solution_start}.*?([\d\.]{{1,}})",
    flags = re.MULTILINE | re.DOTALL
)
match_numbers.findall("<SOLUTION>  0.34  </SOLUTION>")
# Out:
# ['0.34']

# %%
def check_numbers(prompts, completions, answer, **kwargs):
    question = prompts[0][-1]["content"]
    responses = [completion[0]["content"] for completion in completions]

    extracted_responses = [
        guess.group(1)
        if (guess := match_numbers.search(r)) is not None else None \
        for r in responses
    ]

    scores = []
    print('*'*20, f"Question:\n{question}", f"\nAnswer:\n{answer[0]}", f"\nResponse:\n{responses[0]}", f"\nExtracted:\n{extracted_responses[0]}")
    for guess, true_answer in zip(extracted_responses, answer):
        if guess is None:
            scores.append(0)
            continue
        # Convert to numbers
        try:
            true_answer = float(true_answer.strip())
            guess       = float(guess.strip())
            scores.append(1.5 if guess == true_answer else 0.0)
        except:
            scores.append(0)
            continue
    return scores

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
#
# Now set up GRPO Trainer and all configurations!

# %%
max_prompt_length = 256

from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    learning_rate = 5e-6,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.1,
    warmup_ratio = 0.1,
    lr_scheduler_type = "cosine",
    optim = "adamw_torch_fused",
    logging_steps = 1,
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 1, # Increase to 4 for smoother training
    num_generations = 4, # Decrease if out of memory
    max_prompt_length = max_prompt_length,
    max_completion_length = max_seq_length - max_prompt_length,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps = 50,
    save_steps = 50,
    max_grad_norm = 0.1,
    report_to = "none", # Can use Weights & Biases
    output_dir = "outputs",
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 4

# %% [markdown]
# And let's run the trainer! If you scroll up, you'll see a table of rewards. The goal is to see the `reward` column increase!
#
# You might have to wait 150 to 200 steps for any action. You'll probably get 0 reward for the first 100 steps. Please be patient!
#
# | Step | Training Loss | reward    | reward_std | completion_length | kl       |
# |------|---------------|-----------|------------|-------------------|----------|
# | 1    | 0.000000      | 0.125000  | 0.000000   | 200.000000        | 0.000000 |
# | 2    | 0.000000      | 0.072375  | 0.248112   | 200.000000        | 0.000000 |
# | 3    | 0.000000      | -0.079000 | 0.163776   | 182.500000        | 0.000005 |

# %%
trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [
        match_format_exactly,
        match_format_approximately,
        check_answer,
        check_numbers,
    ],
    args = training_args,
    train_dataset = dataset,
)
trainer.train()
# Out:
# Unsloth: Switching to float32 training since model cannot work with float16
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 15 | Num Epochs = 4 | Total steps = 50
# O^O/ \_/ \    Batch size per device = 4 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (4 x 1 x 1) = 4
#  "-____-"     Trainable parameters = 6,522,880/1,006,408,832 (0.65% trained)
# ******************** Question:
# A online retailer wants to analyze the average customer satisfaction of their Agender customers who purchase through different channels. They notice that the Average Customer Satisfaction (ACS) for Agender customers who buy online is 7.2/10, while ACS for those who buy in-store is 4.9/10. If they have a total of 4 Agender customers buying online and 9 Agender customers buying in-store, what is the average difference in ACS between these two groups?
# Answer:
# 13
# Response:
# <start_working_out>
# Let $O$ be the set of Agender customers who buy online, and $I$ be the set of Agender customers who buy in-store.
# We are given that $|O| = 4$ and $|I| = 9$.
# The ACS for Agender customers who buy online is 7.2/10, and the ACS for Agender customers who buy in-store is 4.9/10.
# Let $A_o$ be the ACS for Agender customers who buy online, and $A_i$ be the ACS for Agender customers who buy in-store. Then $A_o = 7.2$ and $A_i = 4.9$.
# We want to find the average difference in ACS between these two groups.
# The difference in ACS between the two groups is $A_o - A_i = 7.2 - 4.9 = 2.3$.
# The total number of Agender customers is $|O| + |I| = 4 + 9 = 13$.
# The average difference in ACS between the two groups is the average of these differences:
# $\frac{A_o - A_i}{2} = \frac{2.3}{2} = 1.15$.
# However, the question asks for the average difference in ACS between these two groups. We can interpret this as the average of the absolute differences between the ACS scores.
# The absolute difference between ACS for online and in-store is $|7.2 - 4.9| = 2.3$.
# The absolute difference between ACS for online and online and in-store is $|7.2 - 4.9| = 2.3$.
# The average difference in ACS between these two groups is $\frac{2.3}{2} = 1.15$.
#
# We are asked for the average difference in ACS between these two groups.
# Let $A_o$ be the ACS for online customers and $A_i$ be the ACS for in-store customers.
# $A_o = 7.2$ and $A_i = 4.9$.
# The number of online customers is 4, and the number of in-store customers is 9.
# The total ACS is $4 \times 7.2 + 9 \times 4.9 = 28.8 + 44.1 = 73$.
# The average ACS is $\frac{73}{13} \approx 5.615$.
# The difference in ACS between online and in-store is $7.2 - 4.9 = 2.3$.
# The average difference in ACS between these two groups is $\frac{2.3}{2} = 1.15$.
# However, this is not the average difference.
#
# Let $A_o$ be the average ACS for online customers, and $A_i$ be the average ACS for in-store customers.
# $A_o = 7.2/10 = 0.72$ and $A_i = 4.9/10 = 0.49$.
# The number of online customers is 4, and the number of in-store customers is 9.
# The total ACS is $4 \times 0.72 + 9 \times 0.49 = 2.88 + 4.41 = 7.29$.
# The average ACS difference is $\frac{7.29}{13
# Extracted:
# None
#     <div>
#
#       <progress value='42' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [42/50 49:32 < 09:54, 0.01 it/s, Epoch 2.73/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completion_length</th>
#       <th>kl</th>
#       <th>rewards / match_format_exactly</th>
#       <th>rewards / match_format_approximately</th>
#       <th>rewards / check_answer</th>
#       <th>rewards / check_numbers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>768.000000</td>
#       <td>0.000017</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>-0.500000</td>
#       <td>0.577350</td>
#       <td>441.250000</td>
#       <td>0.000393</td>
#       <td>0.000000</td>
#       <td>-0.500000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>768.000000</td>
#       <td>0.000016</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>-0.500000</td>
#       <td>0.577350</td>
#       <td>582.250000</td>
#       <td>0.000128</td>
#       <td>0.000000</td>
#       <td>-0.500000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>-0.750000</td>
#       <td>0.500000</td>
#       <td>587.500000</td>
#       <td>0.000373</td>
#       <td>0.000000</td>
#       <td>-0.750000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>0.250000</td>
#       <td>0.500000</td>
#       <td>204.250000</td>
#       <td>0.000172</td>
#       <td>0.000000</td>
#       <td>0.250000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>-0.500000</td>
#       <td>0.577350</td>
#       <td>672.000000</td>
#       <td>0.000310</td>
#       <td>0.000000</td>
#       <td>-0.500000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.750000</td>
#       <td>0.866025</td>
#       <td>178.000000</td>
#       <td>0.000440</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.750000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>-0.500000</td>
#       <td>0.577350</td>
#       <td>578.000000</td>
#       <td>0.000153</td>
#       <td>0.000000</td>
#       <td>-0.500000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>255.250000</td>
#       <td>0.000613</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>768.000000</td>
#       <td>0.000033</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>319.000000</td>
#       <td>0.000447</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.000100</td>
#       <td>-0.250000</td>
#       <td>0.500000</td>
#       <td>107.750000</td>
#       <td>0.002770</td>
#       <td>0.000000</td>
#       <td>-0.250000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000000</td>
#       <td>-0.750000</td>
#       <td>0.500000</td>
#       <td>724.000000</td>
#       <td>0.000176</td>
#       <td>0.000000</td>
#       <td>-0.750000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>752.000000</td>
#       <td>0.000025</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.000000</td>
#       <td>0.125000</td>
#       <td>1.030776</td>
#       <td>311.000000</td>
#       <td>0.000223</td>
#       <td>0.000000</td>
#       <td>-0.250000</td>
#       <td>0.000000</td>
#       <td>0.375000</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.000100</td>
#       <td>0.000000</td>
#       <td>0.816497</td>
#       <td>375.000000</td>
#       <td>0.001522</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.000000</td>
#       <td>-0.750000</td>
#       <td>0.500000</td>
#       <td>698.250000</td>
#       <td>0.000193</td>
#       <td>0.000000</td>
#       <td>-0.750000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.000400</td>
#       <td>-1.000000</td>
#       <td>0.816497</td>
#       <td>472.500000</td>
#       <td>0.008872</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000000</td>
#       <td>0.500000</td>
#       <td>0.577350</td>
#       <td>290.750000</td>
#       <td>0.000735</td>
#       <td>0.000000</td>
#       <td>0.500000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>768.000000</td>
#       <td>0.000156</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.000000</td>
#       <td>-0.250000</td>
#       <td>0.500000</td>
#       <td>370.500000</td>
#       <td>0.000496</td>
#       <td>0.000000</td>
#       <td>-0.250000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.000000</td>
#       <td>-0.500000</td>
#       <td>0.577350</td>
#       <td>645.500000</td>
#       <td>0.000632</td>
#       <td>0.000000</td>
#       <td>-0.500000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.000000</td>
#       <td>-0.250000</td>
#       <td>0.500000</td>
#       <td>458.250000</td>
#       <td>0.000365</td>
#       <td>0.000000</td>
#       <td>-0.250000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>717.000000</td>
#       <td>0.000204</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.000000</td>
#       <td>-0.250000</td>
#       <td>0.500000</td>
#       <td>488.000000</td>
#       <td>0.000144</td>
#       <td>0.000000</td>
#       <td>-0.250000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.000000</td>
#       <td>0.750000</td>
#       <td>1.554563</td>
#       <td>540.000000</td>
#       <td>0.001017</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.750000</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.000000</td>
#       <td>-0.750000</td>
#       <td>0.500000</td>
#       <td>684.750000</td>
#       <td>0.000113</td>
#       <td>0.000000</td>
#       <td>-0.750000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>750.500000</td>
#       <td>0.000030</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
# ******************** Question:
# ** in a gender-diverse market, customers spent an average of $273.10 on online purchases from the genderfluid + online segment. if 52.9% of these customers used the online purchase channel, how much revenue did they generate?
# Answer:
# 1365.50
# Response:
# <start_working_out>
# Let the average amount spent by customers on online purchases from the genderfluid + online segment be $273.10.
# Let the percentage of these customers who used the online purchase channel be 52.9%.
# We want to find the total revenue generated by these customers.
#
# We can calculate the revenue by multiplying the average amount spent by the percentage of customers using the online purchase channel.
# Revenue = Average amount spent * Percentage of customers using online purchase channel
# Revenue = $273.10 * 52.9%
# Revenue = $273.10 * 0.529
# Revenue = $145.3759
#
# Rounding to the nearest dollar, the revenue generated is $145.38.
#
# <SOLUTION>
# Revenue = $145.38
# Extracted:
# 145.38
# ******************** Question:
# In the Mixed purchase channel, customers have a discount usage rate of 50.6%. If the loyalty program membership rate is 49.7%, and the top product categories are Electronics (7.1%), Software & Apps (5.9%), and Home Appliances (5.3%), how much revenue does the store generate from non-loyalty members in this channel, assuming an average purchase amount of $279.90?
# Answer:
# 47
# Response:
# <start_working_out>
# Let $R_L$ be the revenue generated from loyalty program members, $R_N$ be the revenue generated from non-loyalty members, and $R_T$ be the revenue generated from the top product categories.
# We are given that the discount usage rate is 50.6%, so the percentage of sales that are discounted is 50.6%.
# We are given that the loyalty program membership rate is 49.7%, so the percentage of sales that are members is 49.7%.
# The top product categories are Electronics (7.1%), Software & Apps (5.9%), and Home Appliances (5.3%).
# The average purchase amount is $279.90.
# We want to find the revenue generated from non-loyalty members in this channel.
#
# Let $N$ be the number of non-loyalty members.
# The total revenue from loyalty program members is $R_L = 0.506 \times R_T$.
# The total revenue from non-loyalty members is $R_N = (1 - 0.497) \times R_T = 0.503 \times R_T$.
# The revenue from the top product categories is $R_T = 7.1 + 5.9 + 5.3 = 18.3$.
#
# We want to find $R_N$, the revenue from non-loyalty members.
# $R_N = 0.503 \times R_T = 0.503 \times 18.3 = 9.2439$.
# However, the problem asks for the revenue generated from non-loyalty members, not the average revenue.
# We are given that the average purchase amount is $279.90.
# Let $x$ be the revenue generated from non-loyalty members.
# The total revenue from loyalty program members is $0.506 R_T$.
# The total revenue from non-loyalty members is $R_N = (1 - 0.497) R_T = 0.503 R_T$.
# The revenue from the top product categories is $7.1 + 5.9 + 5.3 = 18.3$.
# The total revenue is $R_L + R_N + R_T = 0.506 R_T + 0.503 R_T + 18.3 = 1.009 R_T + 18.3$.
# We are given that the average purchase amount is $279.90$.
# We are asked to find how much revenue the store generates from non-loyalty members in this channel, assuming an average purchase amount of $279.90.
#
# Let $R_L$ be the revenue from loyalty program members, $R_N$ be the revenue from non-loyalty members, and $R_T$ be the revenue from the top product categories.
# The total revenue is $R_L + R_N + R_T$.
# The discount usage rate is 50.6%, so the percentage of sales that are discounted is 50.6%.
# The membership rate is 49.7%, so the percentage of sales that are members is 49.7%.
# The top product categories are Electronics (7.1%), Software & Apps (5.9%), and Home Appliances (5.3%).
# The average purchase amount is $2
# Extracted:
# None
# ******************** Question:
# Determine the average purchase amount of customers in the segment "Toys & Games + Discount Usage: True". There are 27 customers, and each customer spends an average of $285.67 on toys and games with discount usage true. What is the average purchase amount for these customers?
# Answer:
# 286.11
# Response:
# <start_working_out>
# We are given that there are 27 customers.
# Each customer spends an average of $285.67 on toys and games with discount usage true.
# We want to find the average purchase amount for these customers.
# Let $A$ be the average purchase amount for the "Toys & Games + Discount Usage: True" segment.
# The total amount spent by all customers in this segment is $27 \times 285.67$.
# Since each customer spends an average of $285.67 on toys and games with discount usage true, the average purchase amount for these customers is $285.67$.
# However, the problem asks for the average purchase amount for these customers.
# The total spend for this segment is $27 \times 285.67 = 7847.59$.
# The average purchase amount for these customers is $\frac{7847.59}{27} \approx 285.67$.
# But we are given that each customer spends an average of $285.67$.
# Let's rephrase the question.
# We are given that there are 27 customers.
# Each customer spends an average of $285.67 on toys and games with discount usage true.
# We want to find the average purchase amount for these customers.
# The total amount spent by all customers in this segment is $27 \times 285.67$.
# $27 \times 285.67 = 27 \times (280 + 5.67) = 27 \times 280 + 27 \times 5.67 = 7560 + 27 \times 5.67$
# $27 \times 5.67 = 27 \times (5 + 0.67) = 27 \times 5 + 27 \times 0.67 = 135 + 27 \times 0.67$
# $27 \times 0.67 = 27 \times (0.6 + 0.07) = 27 \times 0.6 + 27 \times 0.07 = 16.2 + 1.89 = 18.09$
# So, $27 \times 285.67 = 7560 + 18.09 = 7578.09$
# The average purchase amount is $\frac{7578.09}{27} \approx 285.67$.
# However, we are given that each customer spends an average of $285.67$.
# So, the total amount spent is $27 \times 285.67 = 7847.59$.
# The average purchase amount is $\frac{7847.59}{27} \approx 285.67$.
#
# Let $x_i$ be the purchase amount of the $i$-th customer.
# We are given that the average purchase amount of customers in the segment "Toys & Games + Discount Usage: True" is $285.67$.
# There are 27 customers.
# The total purchase amount is $27 \times 285.67 = 7847.59$.
# The average purchase amount for these
# Extracted:
# None
# ******************** Question:
# an e-commerce company wants to compare the loyalty program membership rates among their different customer segments. they find that 25% of their agender customers who purchase online are part of the loyalty program, while 50% of their agender customers who buy through mixed channels are loyal members. if they have a total of 4 agender customers buying online and 6 agender customers buying through mixed channels, what is the percentage difference in loyalty membership rates between these two groups?
# Answer:
# 100
# Response:
# <start_working_out>
# Let $A_o$ be the set of agender customers who purchase online, and $M$ be the set of agender customers who buy through mixed channels.
# We are given that $|A_o| = 4$ and $|M| = 6$.
# The number of agender customers who are part of the loyalty program is 25% of those who purchase online, so the number of such customers is $0.25 \times |A_o| = 0.25 \times 4 = 1$.
# The number of agender customers who are loyal members is 50% of those who buy through mixed channels, so the number of such customers is $0.50 \times |M| = 0.50 \times 6 = 3$.
# The total number of agender customers is $4 + 6 = 10$.
# The total number of loyalty program members is 1. The total number of members who are loyal members is 3.
# The percentage of agender customers who are loyal members is $\frac{3}{10} \times 100\% = 30\%$.
# The percentage of agender customers who are part of the loyalty program is $\frac{1}{10} \times 100\% = 10\%$.
# The percentage difference in loyalty membership rates between these two groups is
# $\frac{\text{Loyalty members}}{\text{Part of loyalty program members}} \times 100\% = \frac{3}{1} \times 100\% = 300\%$.
# However, this is not the correct interpretation of the problem. We want to find the percentage difference in loyalty membership rates between the two groups.
# Let $L_o$ be the number of agender customers who are part of the loyalty program, and $M_o$ be the number of agender customers who buy through mixed channels.
# We are given $L_o = 0.25 \times |A_o| = 0.25 \times 4 = 1$ and $M_o = 0.50 \times |M| = 0.50 \times 6 = 3$.
# The total number of agender customers is $4 + 6 = 10$.
# The number of loyalty members is 1. The number of loyal members is 3.
# The percentage difference in loyalty membership rates is
# $\frac{\text{Loyal members}}{\text{Total members}} \times 100 = \frac{3}{10} \times 100 = 30\%$.
#
# Let $L_m$ be the number of agender customers who are part of the loyalty program, and $M_m$ be the number of agender customers who buy through mixed channels.
# We are given that 25% of agender customers who purchase online are part of the loyalty program, and 50% of agender customers who buy through mixed channels are loyal members.
# We are given that there are 4 agender customers purchasing online and 6 agender customers buying through mixed channels.
# So, the number of agender customers who are part of the loyalty program is $0.25 \times 4 = 1$.
# The number of agender customers who are loyal members is $0.50 \times 6 = 3$.
# The total number of agender customers is $4 + 6 = 10$.
# The percentage difference in loyalty membership rates is
# $\frac{
# Extracted:
# None
# ******************** Question:
# The e-commerce website has a "Wants-based" customer segment, which accounts for 25% of total customers. The average order value from this segment is $125. If the website has a total of 1200 customers, what was the revenue generated from these Wants-based customer segment orders?
# Answer:
# $37500
# Response:
# <start_working_out>
# Let $N$ be the total number of customers, so $N = 1200$.
# Let $W$ be the percentage of customers in the Wants-based segment, so $W = 25\% = 0.25$.
# Let $A$ be the average order value from the Wants-based segment, so $A = \$125$.
# We want to find the revenue generated from the orders of the Wants-based segment.
# The number of customers in the Wants-based segment is $W \times N = 0.25 \times 1200 = 300$.
# The total revenue generated from the orders of the Wants-based segment is the number of orders multiplied by the average order value.
# Revenue = $300 \times A = 300 \times 125 = 37500$.
#
# <SOLUTION>
# The revenue generated from these Wants-based customer segment orders was $37,500.
# Extracted:
# 37
# ******************** Question:
# ** the loyalty program segment has a discount usage rate of 54.6%. if this segment has a total purchase amount of $128282.01, what is the average discount amount used by customers in this segment?
# Answer:
# 5.46
# Response:
# <start_working_out>
# Let the total purchase amount of the loyalty program segment be $T = 128282.01$.
# The discount usage rate is $r = 54.6\% = 0.546$.
# The number of customers in the loyalty program segment is $N$.
# The discount amount used by each customer is $D$.
# The total discount amount used by all customers is $N \times D$.
# The total discount usage rate is the ratio of the total discount amount to the total purchase amount.
# So, $r = \frac{N \times D}{T}$.
# We are given that $r = 0.546$ and $T = 128282.01$.
# We want to find the average discount amount used by customers in this segment, which is $\frac{N \times D}{T}$.
# We can rearrange the formula to solve for $N \times D$:
# $N \times D = r \times T$
# $N \times D = 0.546 \times 128282.01$
# $N \times D = 70999.49782$
# Therefore, the average discount amount used by customers in this segment is approximately $70999.50$.
# However, we are given that the discount usage rate is 54.6%, which means that the percentage of the purchase amount that is discounted is 54.6%.
# So, $D = 0.546 \times T = 0.546 \times 128282.01 = 70999.49782$.
# The average discount amount used by customers in this segment is $70999.50$.
# Let's assume there are $N$ customers. The total purchase amount is $128282.01$. The discount usage rate is 54.6%.
# The total discount amount is $0.546 \times 128282.01$.
# The average discount amount used by customers in this segment is $\frac{0.546 \times 128282.01}{N}$.
# Since we are given the total purchase amount, we can calculate the average discount amount used by customers in this segment.
# $N \times D = 0.546 \times 128282.01$
# $N \times D = 70999.49782$
# We can approximate the average discount amount to the nearest dollar.
# $N \times D \approx 71000$
# However, we are given that the discount usage rate is 54.6%.
# Let $N$ be the number of customers. Then the total discount amount is $0.546 \times 128282.01 = 70999.49782$.
# The average discount amount is $\frac{70999.49782}{N}$.
# We are given that the total purchase amount is $128282.01$. We can approximate the number of customers as $N$.
# The average discount amount is $0.546 \times 128282.01 \approx 70999.49782$.
# If we assume there are 1000 customers,
# Extracted:
# None
# ******************** Question:
# ** a customer analysis company received data on customer ages and product categories. the ages are 49, 24, 49, and 26. total revenue generated from office supplies is $426.22, sports & outdoors is $78.71, food & beverages is $222.22, gardening & outdoors is $258.02, and clothing is $278.78. what is the total average age of all customers?
# Answer:
# 37
# Response:
# <start_working_out>
# We need to calculate the average age of all customers.
# Let's list the ages: 49, 24, 49, 26
# Total number of customers = 4
# The average age is the sum of the ages divided by the number of customers.
# Average age = $\frac{49 + 24 + 49 + 26}{4}$
# Average age = $\frac{148}{4}$
# Average age = 37
# <SOLUTION>37
# Extracted:
# 37
# ******************** Question:
# ** online purchases made by smartphone users in the "sports & outdoors" category have a discount usage rate of 50%. if this segment accounts for 10.6% of all customers, and the average order value is $283.29, what percentage increase would be needed in sales to reach an overall revenue goal of $30,000 from these specific online purchases?
# Answer:
# 439
# Response:
# <start_working_out>
# Let's break this problem down step-by-step:
#
# 1. **Calculate the discount usage rate:** The discount usage rate is 50%, meaning 50% of the total orders are discounted.
# 2. **Calculate the number of orders in the "sports & outdoors" segment:** The segment accounts for 10.6% of all customers, so there are 10.6% * Total Customers = 0.106 * Total Customers.
# 3. **Calculate the number of orders in the segment:**  Let's assume the total number of customers is 'T'.  Then, the number of orders in the "sports & outdoors" segment is 0.106 * T.
# 4. **Calculate the total value of the discounted orders:** The average order value is $283.29, and the discount is 50%, so the value of discounted orders is 0.50 * 0.106 * T = 0.053 * T.
# 5. **Calculate the total value of all orders:**  The total value of all orders is the average order value multiplied by the total number of orders.  We know the segment represents 10.6% of all customers, so the total number of orders is 0.106 * T.  Therefore, the total value of all orders is 283.29 * 0.106 * T = 30.00 * T.
# 6. **Calculate the increase in sales needed:**  The desired overall revenue is $30,000.  The increase in sales needed is the difference between the total value and the current total value.  So, the increase is $30,000 - $30.00 * T = $30,000 - $30.00 * T.
#
# 7. **Calculate the percentage increase needed:**  The percentage increase needed is the increase in sales needed divided by the current total value, multiplied by 100.
#
# <end_working_out>
# Therefore, the percentage increase needed in sales is $\frac{30000 - 30.00 * T}{30.00 * T} \times 100 = \frac{30000}{30.00 * T} - 100$.
#
# However, we need to find a numerical answer. Let's re-evaluate and assume the total number of customers is 100.
#
# 1. Discount usage rate = 50%
# 2. Orders in "sports & outdoors" = 10.6% of 100 = 10.6
# 3. Orders in "sports & outdoors" = 0.106 * 100 = 10.6
# 4. Value of discounted orders = 0.50 * 10.6 * 283.29 = 14.3 * 283.29 = 4068.387
# 5. Total value of all orders = 283.29 * 100 = 28329
# 6. Increase in sales needed = 30000 - 28329 = 1671
# 7. Percentage increase needed = (1671 / 28329) * 100 ≈ 5.97%
#
# Let's assume the total number of customers is 200.
# Extracted:
# None
# ******************** Question:
# ** The Agender+Packages customer segment has a loyalty program membership rate of 25.0% and an average customer satisfaction rating of 5.5/10. If there are only 4 customers in this segment, and the total purchase amount for these customers is $1021.37, what is the total revenue generated by loyal customers in this segment?
#
# **
# Answer:
# 258.29
# Response:
# <start_working_out>
# Let $R$ be the total revenue generated by loyal customers in this segment.
# The loyalty program membership rate is 25.0%, which means that 25.0% of the total purchase amount is generated by loyal customers.
# The average customer satisfaction rating is 5.5/10, which is 0.55.
# There are 4 customers in this segment.
# The total purchase amount for these customers is $1021.37.
#
# We can calculate the revenue generated by the 4 loyal customers as follows:
# Revenue generated by loyal customers = Loyalty program membership rate * Average customer satisfaction rating * Number of customers
# Revenue generated by loyal customers = 0.25 * 0.55 * 4
# Revenue generated by loyal customers = 0.25 * 0.55 * 4 = 0.25 * 2.2 = 0.55
#
# Therefore, the total revenue generated by loyal customers in this segment is $0.55.
#
# <SOLUTION>
# Total revenue generated by loyal customers = 0.25 * 0.55 * 4 = 0.55
#
# Extracted:
# 0.25
# ******************** Question:
# ** the online segment of a retail business has seen a significant increase in sales through social media influence. if 26.8% of customers are influenced by high-social-media, and they spend an average of $284.30 per order, while the remaining customers spend an average of $262.80 per order, what is the total revenue generated from these two groups if there were a total of 268 orders?
# Answer:
# 147,095
# Response:
# <start_working_out>
# Let $N_1$ be the number of customers influenced by high-social-media, and $N_2$ be the number of customers who do not influence high-social-media.
# We are given that 26.8% of customers are influenced by high-social-media, so $N_1 = 0.268 \times 268 = 71.024$. Since the number of customers must be an integer, we can round this to $N_1 = 71$.
# The remaining customers are $N_2 = 268 - N_1 = 268 - 71 = 197$.
# The average spending of customers influenced by high-social-media is $S_1 = 284.30$. The average spending of customers who do not influence high-social-media is $S_2 = 262.80$.
# The total revenue generated by customers influenced by high-social-media is $R_1 = N_1 \times S_1 = 71 \times 284.30 = 20177.30$.
# The total revenue generated by customers who do not influence high-social-media is $R_2 = N_2 \times S_2 = 197 \times 262.80 = 50529.60$.
# The total revenue generated from these two groups is $R = R_1 + R_2 = 20177.30 + 50529.60 = 70706.90$.
# However, we are given that the total number of orders is 268.
# Let $x$ be the number of customers influenced by high-social-media and $y$ be the number of customers who do not influence high-social-media. We are given that $x+y = 268$.
# The total revenue from customers influenced by high-social-media is $R_1 = 0.268 \times 268 \times 284.30 = 71 \times 284.30 = 20177.30$.
# The total revenue from customers who do not influence high-social-media is $R_2 = y \times 262.80 = 262.80y$.
# The total revenue is $R = R_1 + R_2 = 20177.30 + 262.80y$.
# We also know that $x+y = 268$, so $y = 268 - x$.
# Substituting this into the total revenue equation, we get:
# $R = 20177.30 + 262.80(268 - x) = 20177.30 + 262.80(268) - 262.80x = 20177.30 + 68950.4 - 262.80x = 89127.70 - 262.80x$.
# However, we are given that the average spending is $284.30$ for high-social-media customers and $262.80$ for non-high-social-media customers.
# Let
# Extracted:
# None
# ******************** Question:
# ** in the luxury goods product category, customer satisfaction averaged 5.8/10, with 55% of these satisfied customers being loyalty program members. if there were 20 customers in this segment and 11 out of these loyal customers made a repeat purchase, what percentage of repeat purchases was attributed to the loyalty program?
# Answer:
# 100%
# Response:
# <start_working_out>
# Let $N$ be the total number of customers in the segment, so $N = 20$.
# Let $S$ be the average customer satisfaction rating, so $S = 5.8/10 = 0.58$.
# Let $L$ be the number of loyal customers, so $L = 11$.
# Let $R$ be the number of repeat purchases made by loyal customers, so $R = 11$.
# We want to find the percentage of repeat purchases attributed to the loyalty program.
# Let $P$ be the percentage of repeat purchases attributed to the loyalty program.
# The total number of repeat purchases is 11.
# The number of loyal customers is 11.
# The loyalty program members are the loyal customers, so there are 11 loyal customers.
# The percentage of repeat purchases attributed to the loyalty program is given by:
# $P = \frac{\text{Number of repeat purchases attributed to loyalty program}}{\text{Total number of repeat purchases}} \times 100$
# $P = \frac{R}{L} \times 100$
# $P = \frac{11}{11} \times 100 = 1 \times 100 = 100\%$
# Therefore, the percentage of repeat purchases attributed to the loyalty program is 100%.
#
# <SOLUTION>100%
# Extracted:
# 100
# ******************** Question:
# an e-commerce website received orders from 412 customers. the total purchase amount was $123,456. what is the average purchase amount per customer?
# Answer:
# 299.5
# Response:
# <start_working_out>
# To find the average purchase amount per customer, we need to divide the total purchase amount by the number of customers.
# Total purchase amount = $123,456
# Number of customers = 412
# Average purchase amount per customer = $\frac{123456}{412}$
# Average purchase amount per customer = $303.75$
# <END_WORKING_OUT>
# Extracted:
# None
# ******************** Question:
# The Baby Products segment saw a surge in online sales, with 34.1% of customers making purchases through this channel. If there were 41 total customers in this segment and the average order value was $272.50, what is the total revenue generated from online orders?
# Answer:
# 41
#
# Step 2: Calculate the number of customers who made online orders
# Customers who made online orders = 41 × 0.341 = <<41*0.341=13.991>>14 customers (round down to 14 since you can't have a fraction of a customer)
#
# Step 3: Calculate the total revenue from online orders
# Total revenue from online orders = 14 × $272.50 = <<14*272.5=3830>>
# Response:
# <start_working_out>
# Let $N$ be the total number of customers in the Baby Products segment, so $N = 41$.
# Let $p$ be the percentage of customers making purchases through online sales, so $p = 34.1\% = 0.341$.
# Let $V$ be the average order value for online orders, so $V = $272.50$.
# We want to find the total revenue generated from online orders.
#
# First, we find the number of customers making online purchases:
# Number of online customers = $N \times p = 41 \times 0.341 = 13.921$. Since the number of customers must be an integer, we can round this to 14.
# However, we are given the average order value, so we can use the number of online customers directly.
#
# The total revenue from online orders is the number of online customers multiplied by the average order value.
# Total revenue = Number of online customers $\times$ Average order value
# Total revenue = $13.921 \times 272.50$
# Total revenue = $3784.6375$
#
# However, we should round the number of online customers to the nearest integer.
# Number of online customers $\approx 14$.
# Total revenue = $14 \times 272.50 = 3855$
#
# Alternatively, we can calculate the number of online customers as $0.341 \times 41 = 13.921$. Since the number of customers must be an integer, we can round to the nearest integer, which is 14.
# The total revenue generated from online orders is the number of online customers multiplied by the average order value:
# Total revenue = $14 \times 272.50 = 3855$
#
# Let's calculate the total revenue exactly:
# Number of customers = 41
# Online sales percentage = 34.1%
# Average order value = $272.50
# Number of online customers = $41 \times 0.341 = 13.921$
# Total revenue = $13.921 \times 272.50 = 3784.6375$
# Since the number of customers must be an integer, we can round to the nearest integer, which is 3785.
#
# Let's re-read the problem. We are given that there were 41 total customers and the average order value was $272.50. We are asked to find the total revenue generated from online orders.
# Let $N$ be the number of customers in the segment, so $N=41$.
# Let $p$ be the percentage of customers who purchase online, so $p = 34.1\% = 0.341$.
# Let $A$ be the average order value, so $A = $272.50$.
# The number of online customers is $N \times p = 41 \times 0.341 = 13.921$. Since the number of customers must be an integer, we round to 14.
# The total revenue is the number of online customers multiplied by the average order value:
# Total revenue = $14 \times 272.50 = 3855$.
# However, we can also calculate the number of online customers as $0.3
# Extracted:
# None
# ******************** Question:
# The office supplies category saw a 15% increase in sales revenue compared to the previous year. if the category's average order value (aov) is $65, how much more revenue did the website generate from this category last year compared to the previous year if total sales revenue was $12,500?
# Answer:
# 1787
# Response:
# <start_working_out>
# Let $R_p$ be the total sales revenue for the office supplies category last year.
# Let $R_w$ be the total sales revenue for the office supplies category this year.
# We are given that the office supplies category saw a 15% increase in sales revenue compared to the previous year. Therefore,
# $R_w = R_p + 0.15 R_p = 1.15 R_p$
# We are given that the total sales revenue was $12,500. So, $R_p + R_w = 12500$.
# Substituting $R_w = 1.15 R_p$, we have
# $R_p + 1.15 R_p = 12500$
# $2.15 R_p = 12500$
# $R_p = \frac{12500}{2.15} \approx 5820.37$
# Now, we want to find how much more revenue the website generated from this category last year compared to the previous year.
# Let $R_v$ be the revenue generated by the website from the office supplies category last year.
# Let $R_s$ be the revenue generated by the website from the office supplies category this year.
# We are given that the average order value (aov) of the category is $65.
# So, $R_s = Aov \times R_p = 65 \times R_p = 65 \times \frac{12500}{2.15} = 65 \times 5820.37 \approx 383355.45$
# We want to find the difference between the revenue generated by the website last year and the revenue generated by the website this year.
# $R_v = R_s - R_p = 383355.45 - 5820.37 = 377535.08$
# Alternatively, we can find the increase in revenue from the website compared to the previous year.
# The increase in revenue is $R_w - R_p = 1.15 R_p - R_p = 0.15 R_p = 0.15 \times \frac{12500}{2.15} = 0.15 \times 5820.37 \approx 873.0565$
# However, the question asks how much more revenue the website generated from this category last year compared to the previous year.
# The difference is $R_v - R_p = R_s - R_p = 383355.45 - 5820.37 = 377535.08$.
# The website generated more revenue from the office supplies category last year than the previous year.
# The amount more revenue generated by the website last year compared to the previous year is $377535.08.
#
# Final Answer: The final answer is $\boxed{377535}$
# Extracted:
# None
# ******************** Question:
# ** a customer analysis company received data on customer ages and product categories. the ages are 49, 24, 49, and 26. total revenue generated from office supplies is $426.22, sports & outdoors is $78.71, food & beverages is $222.22, gardening & outdoors is $258.02, and clothing is $278.78. what is the total average age of all customers?
# Answer:
# 37
# Response:
# <start_working_out>
# We need to calculate the average age of all customers.
# We have the following ages: 49, 24, 49, 26
# Total number of customers = 4
# We need to find the average age.
# Average age = Total age / Number of customers
# Average age = (49 + 24 + 49 + 26) / 4
# Average age = (158) / 4
# Average age = 39.5
#
# <SOLUTION>39.5
# Extracted:
# 39.5
# ******************** Question:
# ** the loyalty program segment has a discount usage rate of 54.6%. if this segment has a total purchase amount of $128282.01, what is the average discount amount used by customers in this segment?
# Answer:
# 5.46
# Response:
# <start_working_out>
# Let the total purchase amount be $T = 128282.01$.
# The discount usage rate is 54.6%, which means the discount amount used is 54.6% of the total purchase amount.
# Discount amount = 0.546 * T = 0.546 * 128282.01
# Discount amount = 70770.77856
#
# The average discount amount used by customers in this segment is $70770.78$.
# </start_working_out>
#
# <SOLUTION>70770.78</SOLUTION>
# Extracted:
# 70770.78
# ******************** Question:
# In the Mixed purchase channel, customers have a discount usage rate of 50.6%. If the loyalty program membership rate is 49.7%, and the top product categories are Electronics (7.1%), Software & Apps (5.9%), and Home Appliances (5.3%), how much revenue does the store generate from non-loyalty members in this channel, assuming an average purchase amount of $279.90?
# Answer:
# 47
# Response:
# <start_working_out>
# Let's define the variables:
# - $R_L = $279.90 (Average purchase amount)
# - $M = 50.6% (Discount usage rate)
# - $L = 49.7% (Loyalty program membership rate)
# - $C = 7.1% (Top product category - Electronics)
# - $A = 5.9% (Top product category - Software & Apps)
# - $B = 5.3% (Top product category - Home Appliances)
#
# We want to find the revenue generated by non-loyalty members.  First, we need to calculate the revenue from each product category for non-loyalty members.
#
# Revenue from Electronics:
# $R_E = M * $C = 0.506 * 7.1% = 0.35862%
# $R_E = 0.35862 * $279.90 = $9.798738
#
# Revenue from Software & Apps:
# $R_A = M * A = 0.506 * 5.9% = 0.29984%
# $R_A = 0.29984 * $279.90 = $8.593233
#
# Revenue from Home Appliances:
# $R_B = M * B = 0.506 * 5.3% = 0.26618%
# $R_B = 0.26618 * $279.90 = $7.353382
#
# Total revenue from non-loyalty members:
# $R_{non_loyalty} = R_E + R_A + R_B = $9.798738 + $8.593233 + $7.353382 = $25.745353
#
# Therefore, the store generates approximately $25.75 from non-loyalty members in this channel.
#
# <end_working_out>
# Final Answer: The final answer is $\boxed{25.75}$
# Extracted:
# None
# ******************** Question:
# ** in a gender-diverse market, customers spent an average of $273.10 on online purchases from the genderfluid + online segment. if 52.9% of these customers used the online purchase channel, how much revenue did they generate?
# Answer:
# 1365.50
# Response:
# <START_WORKING_OUT>
# Let the total revenue generated by the genderfluid + online segment be $R$.
# The average amount spent by these customers on online purchases is $273.10.
# The percentage of these customers who used the online purchase channel is 52.9%.
# Therefore, the revenue generated by this segment is 52.9% of $273.10.
# R = 0.529 * 273.10
# R = 143.6559
# Rounding to the nearest dollar, the revenue generated by this segment is $144.
#
# <END_WORKING_OUT>
#
# Extracted:
# None
# ******************** Question:
# The e-commerce website has a "Wants-based" customer segment, which accounts for 25% of total customers. The average order value from this segment is $125. If the website has a total of 1200 customers, what was the revenue generated from these Wants-based customer segment orders?
# Answer:
# $37500
# Response:
# <start_working_out>
# Let $N$ be the total number of customers, so $N = 1200$.
# Let $W$ be the percentage of customers in the Wants-based segment, so $W = 25\% = 0.25$.
# Let $A$ be the average order value from the Wants-based segment, so $A = $125$.
# We want to find the revenue generated from the Wants-based customer segment orders.
#
# First, we find the number of customers in the Wants-based segment:
# Number of Wants-based customers = $W \times N = 0.25 \times 1200 = 300$.
#
# Next, we find the total revenue generated from the Wants-based customer segment orders:
# Total revenue = (Number of Wants-based customers) $\times$ (Average order value)
# Total revenue = $300 \times 125 = 37500$.
#
# Therefore, the revenue generated from these Wants-based customer segment orders is $37500.
#
# <SOLUTION>37500</SOLUTION>
# Extracted:
# 37500
# ******************** Question:
# The Baby Products segment saw a surge in online sales, with 34.1% of customers making purchases through this channel. If there were 41 total customers in this segment and the average order value was $272.50, what is the total revenue generated from online orders?
# Answer:
# 41
#
# Step 2: Calculate the number of customers who made online orders
# Customers who made online orders = 41 × 0.341 = <<41*0.341=13.991>>14 customers (round down to 14 since you can't have a fraction of a customer)
#
# Step 3: Calculate the total revenue from online orders
# Total revenue from online orders = 14 × $272.50 = <<14*272.5=3830>>
# Response:
# <start_working_out>
# Let $N$ be the total number of customers in the Baby Products segment, so $N = 41$.
# Let $p$ be the percentage of customers who made purchases through online sales, so $p = 34.1\% = 0.341$.
# Let $O$ be the average order value for online orders, so $O = $272.50$.
# We want to find the total revenue generated from online orders.
#
# First, we find the number of customers who made online orders. This is given by $N \times p = 41 \times 0.341 = 13.921$. Since the number of customers must be an integer, we can round this to 14.
# However, we can also calculate the number of online orders directly. The number of online orders is $O \times N = 272.50 \times 41 = 11352.50$.
# Since the number of orders must be an integer, we can round this to 11353.
#
# The total revenue generated from online orders is the number of online orders multiplied by the average order value.
# Total revenue = $11352.50 \times 0.341 = 3846.3475$.
# Rounding to the nearest dollar, the total revenue is $3846$.
#
# Alternatively, we can calculate the number of online customers as $41 \times 0.341 = 13.921$. Since the number of customers must be an integer, we can round this to 14.
# Then, the total revenue from online orders is $14 \times 272.50 = 3845$.
#
# Let's calculate the exact number of online customers:
# $41 \times 0.341 = 13.921$. Since we must have an integer number of customers, we can round to 14.
# The average order value is $272.50$.
# The total revenue from online orders is $14 \times 272.50 = 3845$.
#
# Let's assume we need to find the exact number of online customers.
# The number of online customers is $41 \times 0.341 = 13.921$. Since we cannot have a fraction of a customer, we must have made a mistake.
# The problem states that 34.1% of customers made purchases through this channel. So, the number of customers who made online orders is $0.341 \times 41 = 13.921$. Since the number of customers must be an integer, we can round this to 14.
# The total revenue generated from online orders is $14 \times 272.50 = 3845$.
#
# However, we can also calculate the number of online orders as $\frac{41 \times 0.341}{0.341} = 41$.
# Total revenue = $41 \times 272.50 = 11352.50$.
#
# We are given that the average order value is $272.50$.
# Let $x$ be the number of online orders.
# The total revenue is $272.50x$.
# We know that $41 \times 0.341 = 1
# Extracted:
# None
# ******************** Question:
# ** in the luxury goods product category, customer satisfaction averaged 5.8/10, with 55% of these satisfied customers being loyalty program members. if there were 20 customers in this segment and 11 out of these loyal customers made a repeat purchase, what percentage of repeat purchases was attributed to the loyalty program?
# Answer:
# 100%
# Response:
# <start_working_out>
# Let $N$ be the total number of customers in the segment, so $N = 20$.
# Let $S$ be the average customer satisfaction rating, so $S = 5.8/10 = 0.58$.
# Let $L$ be the number of loyalty program members, so $L = 55\% \times 20 = 0.55 \times 20 = 11$.
# Let $R$ be the number of repeat purchases made by loyal customers, so $R = 11$.
# We want to find the percentage of repeat purchases attributed to the loyalty program.
# Let $p$ be the percentage of repeat purchases attributed to the loyalty program.
# Then, $p = \frac{R}{N} \times S = \frac{11}{20} \times 0.58 = 0.55 \times 0.58 = 0.319$.
# So, $p = 0.319$, which is approximately $31.9\%$.
#
# <SOLUTION>
# The percentage of repeat purchases attributed to the loyalty program is approximately 31.9%.
# Extracted:
# 31.9
# ******************** Question:
# ** The Agender+Packages customer segment has a loyalty program membership rate of 25.0% and an average customer satisfaction rating of 5.5/10. If there are only 4 customers in this segment, and the total purchase amount for these customers is $1021.37, what is the total revenue generated by loyal customers in this segment?
#
# **
# Answer:
# 258.29
# Response:
# <start_working_out>
# Let $N$ be the number of customers in the Agender+Packages segment, which is given as $N = 4$.
# Let $L$ be the loyalty program membership rate, which is given as $L = 25.0\% = 0.25$.
# ...
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.000000</td>
#       <td>-0.250000</td>
#       <td>0.500000</td>
#       <td>370.500000</td>
#       <td>0.000496</td>
#       <td>0.000000</td>
#       <td>-0.250000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.000000</td>
#       <td>-0.500000</td>
#       <td>0.577350</td>
#       <td>645.500000</td>
#       <td>0.000632</td>
#       <td>0.000000</td>
#       <td>-0.500000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.000000</td>
#       <td>-0.250000</td>
#       <td>0.500000</td>
#       <td>458.250000</td>
#       <td>0.000365</td>
#       <td>0.000000</td>
#       <td>-0.250000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>717.000000</td>
#       <td>0.000204</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.000000</td>
#       <td>-0.250000</td>
#       <td>0.500000</td>
#       <td>488.000000</td>
#       <td>0.000144</td>
#       <td>0.000000</td>
#       <td>-0.250000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.000000</td>
#       <td>0.750000</td>
#       <td>1.554563</td>
#       <td>540.000000</td>
#       <td>0.001017</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.750000</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.000000</td>
#       <td>-0.750000</td>
#       <td>0.500000</td>
#       <td>684.750000</td>
#       <td>0.000113</td>
#       <td>0.000000</td>
#       <td>-0.750000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
#       <td>750.500000</td>
#       <td>0.000030</td>
#       <td>0.000000</td>
#       <td>-1.000000</td>
#       <td>0.000000</td>
# ******************** Question:
# an e-commerce company wants to compare the loyalty program membership rates among their different customer segments. they find that 25% of their agender customers who purchase online are part of the loyalty program, while 50% of their agender customers who buy through mixed channels are loyal members. if they have a total of 4 agender customers buying online and 6 agender customers buying through mixed channels, what is the percentage difference in loyalty membership rates between these two groups?
# Answer:
# 100
# Response:
# <start_working_out>
# Let $A_o$ be the set of agender customers who purchase online, and $M_o$ be the set of agender customers who buy through mixed channels.
# We are given that 25% of agender customers who purchase online are part of the loyalty program, so $|A_o \cap L| = 0.25 \times |A_o|$.
# We are given that 50% of agender customers who buy through mixed channels are loyal members, so $|A_o \cap L| = 0.50 \times |M_o|$.
# We have $|A_o| = 4$ and $|M_o| = 6$.
# We want to find the percentage difference in loyalty membership rates between the two groups.
# First, we find the number of agender customers in the loyalty program:
# $|A_o \cap L| = 0.25 \times |A_o| = 0.25 \times 4 = 1$.
# Next, we find the number of agender customers in the mixed channel segment who are loyal members:
# $|A_o \cap L| = 0.50 \times |M_o| = 0.50 \times 6 = 3$.
# The total number of agender customers in the loyalty program is 1. The total number of agender customers in the mixed channel segment is 3.
# The difference in the number of loyal members between the two groups is $|3 - 1| = 2$.
# The percentage difference in loyalty membership rates is $\frac{2}{4} \times 100 = 50\%$.
# The percentage difference in loyalty membership rates between the two groups is 50%.
#
# <SOLUTION>
# The number of agender customers who purchase online is 4.
# The number of agender customers who buy through mixed channels is 6.
# The percentage of agender customers who are part of the loyalty program is 25% of the agender customers who purchase online. So, the number of agender customers in the loyalty program is $0.25 \times 4 = 1$.
# The percentage of agender customers who are loyal members is 50% of the agender customers who buy through mixed channels. So, the number of agender customers in the mixed channel segment who are loyal members is $0.50 \times 6 = 3$.
# The difference in the number of loyal members between the two groups is $3 - 1 = 2$.
# The percentage difference in loyalty membership rates is $\frac{2}{4} \times 100 = 50\%$.
#
# Final Answer: The final answer is $\boxed{50}$
# Extracted:
# 4.
# ******************** Question:
# ** the loyalty program segment has a discount usage rate of 54.6%. if this segment has a total purchase amount of $128282.01, what is the average discount amount used by customers in this segment?
# Answer:
# 5.46
# Response:
# <start_working_out>
# Let the total purchase amount of the loyalty program segment be $T = 128282.01$.
# Let the discount usage rate be $r = 54.6\% = 0.546$.
# We need to find the average discount amount used by customers in this segment.
#
# First, we calculate the total discount amount used by customers in the segment.
# The discount usage rate is 54.6%, so the discount amount is $0.546 \times T$.
# Total discount amount = $0.546 \times 128282.01 = 70719.95506$.
# The average discount amount used by customers in this segment is the total discount amount divided by the number of customers in the segment.
# Average discount amount = $\frac{70719.95506}{N}$, where $N$ is the number of customers in the segment.
# However, we are not given the number of customers in the segment. We can assume that the problem is asking for the average discount amount per customer.
# The discount usage rate is 54.6%, so the percentage of the purchase amount that is discounted is 54.6%.
# The total purchase amount is $128282.01.
# The discount amount used is $0.546 \times 128282.01 = 70719.95506$.
# We need to find the average discount amount used by customers in this segment.
# Average discount amount = $\frac{70719.95506}{N}$, where $N$ is the number of customers in the segment.
# Since we don't know the number of customers, let's assume we are asked to find the average discount amount per customer.
# The discount usage rate is 54.6%, so the discount amount is 54.6% of the total purchase amount.
# Discount amount = $0.546 \times 128282.01 = 70719.95506$
# We need to find the average discount amount used by customers in this segment.
# Average discount amount = $\frac{70719.95506}{N}$, where $N$ is the number of customers in the segment.
# However, we are not given the number of customers in the segment. Let's assume the question is asking for the average discount amount per dollar spent.
# Discount amount = $0.546 \times 128282.01 = 70719.95506$
# Average discount per dollar = $\frac{70719.95506}{128282.01} \approx 0.546$
# However, this is not an exact average.
# We are given the total purchase amount $T = 128282.01$.
# The discount usage rate is 54.6%, so the discount amount is $0.546 \times 128282.01 = 70719.95506$.
# The number of customers in the segment is not given.
# Let's assume the question is asking for the average discount amount per customer.
# Average discount amount = $\frac{70719.95506}{N}$, where $N$
# Extracted:
# None
# ******************** Question:
# The office supplies category saw a 15% increase in sales revenue compared to the previous year. if the category's average order value (aov) is $65, how much more revenue did the website generate from this category last year compared to the previous year if total sales revenue was $12,500?
# Answer:
# 1787
# Response:
# <start_working_out>
# Let $R_L$ be the total sales revenue last year and $R_W$ be the total sales revenue this year. We are given that $R_L = $12,500$ and the sales revenue increased by 15% compared to the previous year. Thus, the increase in sales revenue is $0.15 \times R_L = 0.15 \times 12,500 = 1,875$. The new total sales revenue is $R_L + 1,875 = 12,500 + 1,875 = 14,375$.
#
# Let $A_L$ be the average order value last year and $A_W$ be the average order value this year. We are given that $A_L = $65$. The total sales revenue this year is $R_W = $14,375$.
# The number of orders last year is $N_L = \frac{R_L}{A_L} = \frac{12,500}{65} = 192.315...$. Since the number of orders must be an integer, we can assume that the number of orders last year was approximately 192.
# The number of orders this year is $N_W = \frac{R_W}{A_W} = \frac{14,375}{65} = 217.5$. Since the number of orders must be an integer, we can assume that the number of orders this year was approximately 217.
# The difference in revenue between the website and the category is $R_W - R_L = 14,375 - 12,500 = 1,875$.
# Alternatively, we can find the percentage increase in revenue from the category compared to the previous year.
# The increase in revenue is 15% of the total sales revenue last year, which is $0.15 \times 12,500 = 1875$.
# The website generated this increase in revenue from this category last year compared to the previous year.
# So, the website generated $1875$.
#
# <end_working_out>
# Final Answer: The final answer is $\boxed{1875}$
# Extracted:
# None
# ******************** Question:
# an e-commerce company wants to compare the loyalty program membership rates among their different customer segments. they find that 25% of their agender customers who purchase online are part of the loyalty program, while 50% of their agender customers who buy through mixed channels are loyal members. if they have a total of 4 agender customers buying online and 6 agender customers buying through mixed channels, what is the percentage difference in loyalty membership rates between these two groups?
# Answer:
# 100
# Response:
# <start_working_out>
# Let $A_1$ be the set of agender customers who purchase online, and $A_2$ be the set of agender customers who buy through mixed channels.
# We are given that $|A_1| = 4$ and $|A_2| = 6$.
# The total number of agender customers is $4 + 6 = 10$.
# Let $L_1$ be the set of loyalty program members among $A_1$, and $L_2$ be the set of loyalty program members among $A_2$.
# We are given that 25% of agender customers who purchase online are part of the loyalty program, so $|L_1| = 0.25 \times |A_1| = 0.25 \times 4 = 1$.
# We are given that 50% of agender customers who buy through mixed channels are loyal members, so $|L_2| = 0.50 \times |A_2| = 0.50 \times 6 = 3$.
# The total number of agender customers is 10.
# The total number of loyalty program members is $|L_1| + |L_2| = 1 + 3 = 4$.
# The percentage difference in loyalty membership rates between these two groups is
# $$\frac{|L_1| - |L_2|}{|L_1| + |L_2|} \times 100 = \frac{1 - 3}{1 + 3} \times 100 = \frac{-2}{4} \times 100 = -\frac{1}{2} \times 100 = -50\%$$
# The percentage difference in loyalty membership rates between these two groups is -50%.
#
# <END_WORKING_OUT>
# Extracted:
# None
# ******************** Question:
# an e-commerce website received orders from 412 customers. the total purchase amount was $123,456. what is the average purchase amount per customer?
# Answer:
# 299.5
# Response:
# <start_working_out>
# We are given that the total purchase amount is $123,456 and there are 412 customers. To find the average purchase amount per customer, we divide the total purchase amount by the number of customers.
# Average purchase amount per customer = $\frac{\text{Total purchase amount}}{\text{Number of customers}} = \frac{123456}{412}$
# $\frac{123456}{412} \approx 301.03$
# Therefore, the average purchase amount per customer is approximately $301.03.
#
# <SOLUTION>301.03
# Extracted:
# 301.03
# ******************** Question:
# ** online purchases made by smartphone users in the "sports & outdoors" category have a discount usage rate of 50%. if this segment accounts for 10.6% of all customers, and the average order value is $283.29, what percentage increase would be needed in sales to reach an overall revenue goal of $30,000 from these specific online purchases?
# Answer:
# 439
# Response:
# <start_working_out>
# Let's break this problem down step by step.
#
# 1. **Calculate the value of the discount usage:**
#    - The discount usage rate is 50%, so the discount amount is 50% of $283.29.
#    - Discount amount = 0.50 * $283.29 = $141.645
#
# 2. **Calculate the value of online purchases:**
#    - The segment accounts for 10.6% of all customers, so the value of online purchases is 10.6% of $283.29.
#    - Online purchase value = 0.106 * $283.29 = $30.37954
#
# 3. **Calculate the new revenue target:**
#    - We want to reach a revenue goal of $30,000.
#
# 4. **Calculate the increase in sales needed:**
#    - The increase needed is the difference between the new revenue target and the current revenue:
#    - Increase = $30,000 - $30.37954 = $29,699.62046
#
# 5. **Calculate the percentage increase:**
#    - Divide the increase by the current revenue and multiply by 100:
#    - Percentage increase = ($29,699.62046 / $30,379.54) * 100 ≈ 97.42%
#
# Therefore, a 97.42% increase in sales would be needed to reach the overall revenue goal.
#
# <END_WORKING_OUT>
# Extracted:
# None
# ******************** Question:
# A online retailer wants to analyze the average customer satisfaction of their Agender customers who purchase through different channels. They notice that the Average Customer Satisfaction (ACS) for Agender customers who buy online is 7.2/10, while ACS for those who buy in-store is 4.9/10. If they have a total of 4 Agender customers buying online and 9 Agender customers buying in-store, what is the average difference in ACS between these two groups?
# Answer:
# 13
# Response:
# <start_working_out>
# Let $O$ be the number of Agender customers buying online, and $I$ be the number of Agender customers buying in-store.
# We are given that $O = 4$ and $I = 9$.
# The ACS for Agender customers who buy online is 7.2/10, and the ACS for Agender customers who buy in-store is 4.9/10.
# Let $A_o$ be the average ACS for online customers, and $A_i$ be the average ACS for in-store customers.
# Then $A_o = 7.2/10 = 0.72$ and $A_i = 4.9/10 = 0.49$.
# We want to find the average difference in ACS between the two groups.
# The total ACS for online customers is $O \times A_o = 4 \times 0.72 = 2.88$.
# The total ACS for in-store customers is $I \times A_i = 9 \times 0.49 = 4.41$.
# The average difference in ACS is the total ACS for online customers minus the total ACS for in-store customers, divided by the number of online customers plus the number of in-store customers.
# Average difference = $\frac{2.88 - 4.41}{4 + 9} = \frac{-1.53}{13} \approx -0.11769$.
# Rounded to the nearest tenth, the average difference is -0.1.
#
# <end_working_out>
#
# Extracted:
# None
# ******************** Question:
# The e-commerce website has a "Wants-based" customer segment, which accounts for 25% of total customers. The average order value from this segment is $125. If the website has a total of 1200 customers, what was the revenue generated from these Wants-based customer segment orders?
# Answer:
# $37500
# Response:
# <start_working_out>
# Let $N$ be the total number of customers, so $N = 1200$.
# Let $W$ be the proportion of customers in the Wants-based segment, so $W = 25\% = 0.25$.
# Let $A$ be the average order value from the Wants-based segment, so $A = $125$.
# We want to find the revenue generated from these Wants-based customer segment orders.
#
# First, we find the number of customers in the Wants-based segment.
# Number of customers in the Wants-based segment = $W \times N = 0.25 \times 1200 = 300$.
#
# Next, we find the revenue generated from these orders.
# Revenue = Number of orders $\times$ Average order value
# Revenue = $300 \times 125 = 37500$.
#
# Therefore, the revenue generated from these Wants-based customer segment orders is $37500.
#
# <SOLUTION>37500</SOLUTION>
# Extracted:
# 37500
# TrainOutput(global_step=50, training_loss=4.345561433638068e-05, metrics={'train_runtime': 3682.6325, 'train_samples_per_second': 0.054, 'train_steps_per_second': 0.014, 'total_flos': 0.0, 'train_loss': 4.345561433638068e-05})

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Now let's try the model we just trained!

# %%
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user",   "content": "What is the sqrt of 101?"},
]

text = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt = True, # Must add for generation
    tokenize = False,
)
from transformers import TextStreamer
_ = model.generate(
    **tokenizer(text, return_tensors = "pt").to("cuda"),
    max_new_tokens = 64, # Increase for longer outputs!
    # Recommended Gemma-3 settings!
    temperature = 1.0, top_p = 0.95, top_k = 64,
    streamer = TextStreamer(tokenizer, skip_prompt = True),
)
# Out:
# <start_working_out>
# The square root of 101 is approximately 10.0498756.
# <SOLUTION>
# 10.0498756<end_of_turn>

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
model.save_pretrained("gemma-3")  # Local saving
tokenizer.save_pretrained("gemma-3")
# model.push_to_hub("HF_ACCOUNT/gemma-3", token = "...") # Online saving
# tokenizer.push_to_hub("HF_ACCOUNT/gemma-3", token = "...") # Online saving
# Out:
# ('gemma-3/tokenizer_config.json',
#  'gemma-3/special_tokens_map.json',
#  'gemma-3/tokenizer.model',
#  'gemma-3/added_tokens.json',
#  'gemma-3/tokenizer.json')

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly for deployment! We save it in the folder `gemma-3-finetune`. Set `if False` to `if True` to let it run!

# %%
if False: # Change to True to save finetune!
    model.save_pretrained_merged("gemma-3-finetune", tokenizer)

# %% [markdown]
# If you want to upload / push to your Hugging Face account, set `if False` to `if True` and add your Hugging Face token and upload location!

# %%
if False: # Change to True to upload finetune
    model.push_to_hub_merged(
        "HF_ACCOUNT/gemma-3-finetune", tokenizer,
        token = "hf_..."
    )

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now for all models! For now, you can convert easily to `Q8_0, F16 or BF16` precision. `Q4_K_M` for 4bit will come later!

# %%
if False: # Change to True to save to GGUF
    model.save_pretrained_gguf(
        "gemma-3-finetune",
        quantization_type = "Q8_0", # For now only Q8_0, BF16, F16 supported
    )

# %% [markdown]
# Likewise, if you want to instead push to GGUF to your Hugging Face account, set `if False` to `if True` and add your Hugging Face token and upload location!

# %%
if False: # Change to True to upload GGUF
    model.push_to_hub_gguf(
        "gemma-3-finetune",
        quantization_type = "Q8_0", # Only Q8_0, BF16, F16 supported
        repo_id = "HF_ACCOUNT/gemma-finetune-gguf",
        token = "hf_...",
    )

# %% [markdown]
# Now, use the `gemma-3-finetune.gguf` file or `gemma-3-finetune-Q4_K_M.gguf` file in llama.cpp or a UI based system like Jan or Open WebUI. You can install Jan [here](https://github.com/janhq/jan) and Open WebUI [here](https://github.com/open-webui/open-webui)
#
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
